# %% [markdown]
# # Notebook used for Testing the Data Cleaning

# %%
import numpy as np
import json
import pandas as pd
from urllib.request import urlopen
import scipy.optimize
import random
from collections import defaultdict
import nltk
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import random
from statistics import mode
from sklearn import svm
import matplotlib.pyplot as plt
import patsy
import statsmodels.api as sm

# %% [markdown]
# Rename columns in dataset based on the following key:

# %%
# Read in the dataset
df = pd.read_csv("Questionnaire_Responses.csv")
rename_columns = ["time_submitted", "location", "major", "curr_activity_level", "past_activity_level",
              "exercise_importance", "prior_athlete", "sport_history", "exercise_locations",
              "off_campus_gym_freq", "avg_commute_mwf_off_campus", "avg_commute_tth_off_campus",
              "avg_commute_ss_off_campus", "commute_challenges_mwf_off_campus",
              "commute_challenges_tth_off_campus", "commute_challenges_ss_off_campus",
              "transportation_mwf_off_campus", "transportation_tth_off_campus", "transportation_ss_off_campus",
              "on_campus_gym_freq","avg_commute_mwf_on_campus", "avg_commute_tth_on_campus",
              "avg_commute_ss_on_campus", "commute_challenges_mwf_on_campus",
              "commute_challenges_tth_on_campus", "commute_challenges_ss_on_campus",
              "transportation_mwf_on_campus", "transportation_tth_on_campus", "transportation_ss_on_campus",
              "mwf_passing_gym", "tth_passing_gym", "ss_passing_gym", "main_gym_location","gen_gym_locations",
              "proximity_importance", "equipment_importance", "time_importance", "class_importance",
              "friends_importance", "student_athlete_importance", "other_importance", "main_motivator",
              "attend_gym_times", "email"]
key = zip(df.columns, rename_columns)

# %%
#KEY of questions and columns
for i in key:
    print(i)
# Out:
# ('Timestamp', 'time_submitted')
# ('Where do you live?', 'location')
# ("What's your major?", 'major')
# ('How would you rank your level of activity in regards to exercising PRESENTLY?', 'curr_activity_level')
# ('How would you rank your level of activity in regards to exercising BEFORE UCSD?', 'past_activity_level')
# ('How important is exercising to you?', 'exercise_importance')
# ('Were/Are you a competitive athlete or dancer? CHECK ALL THAT APPLY.', 'prior_athlete')
# ('If yes, what sport(s) did you do?', 'sport_history')
# ('How/Where do you usually exercise? CHECK ALL THAT APPLY.', 'exercise_locations')
# ('How often do you use the gyms OFF campus?', 'off_campus_gym_freq')
# ('How long does it usually take you to get to the gym OFF campus? ONE ANSWER PER ROW [Mon, Wed, Fri]', 'avg_commute_mwf_off_campus')
# ('How long does it usually take you to get to the gym OFF campus? ONE ANSWER PER ROW [Tues, Thurs]', 'avg_commute_tth_off_campus')
# ('How long does it usually take you to get to the gym OFF campus? ONE ANSWER PER ROW [Weekends]', 'avg_commute_ss_off_campus')
# ('Do you face any of the following while going to an OFF campus gym? CHECK ALL THAT APPLY [Mon, Wed, Fri]', 'commute_challenges_mwf_off_campus')
# ('Do you face any of the following while going to an OFF campus gym? CHECK ALL THAT APPLY [Tues, Thurs]', 'commute_challenges_tth_off_campus')
# ('Do you face any of the following while going to an OFF campus gym? CHECK ALL THAT APPLY [Weekends]', 'commute_challenges_ss_off_campus')
# ('What mode of transportation do you use to get to the gym OFF campus? CHECK ALL THAT APPLY [Mon, Wed, Fri]', 'transportation_mwf_off_campus')
# ('What mode of transportation do you use to get to the gym OFF campus? CHECK ALL THAT APPLY [Tues, Thurs]', 'transportation_tth_off_campus')
# ('What mode of transportation do you use to get to the gym OFF campus? CHECK ALL THAT APPLY [Weekend]', 'transportation_ss_off_campus')
# ('How often do you use the gyms ON campus?', 'on_campus_gym_freq')
# ('How long does it usually take you to get to the gym ON campus? ONE ANSWER PER ROW [Mon, Wed, Fri]', 'avg_commute_mwf_on_campus')
# ('How long does it usually take you to get to the gym ON campus? ONE ANSWER PER ROW [Tues, Thurs]', 'avg_commute_tth_on_campus')
# ('How long does it usually take you to get to the gym ON campus? ONE ANSWER PER ROW [Weekends]', 'avg_commute_ss_on_campus')
# ('Do you face any of the following while going to an ON campus gym? CHECK ALL THAT APPLY [Mon, Wed, Fri]', 'commute_challenges_mwf_on_campus')
# ('Do you face any of the following while going to an ON campus gym? CHECK ALL THAT APPLY [Tues, Thurs]', 'commute_challenges_tth_on_campus')
# ('Do you face any of the following while going to an ON campus gym? CHECK ALL THAT APPLY [Weekends]', 'commute_challenges_ss_on_campus')
# ('What mode of transportation do you use to get to the gym ON campus? CHECK ALL THAT APPLY [Mon, Wed, Fri]', 'transportation_mwf_on_campus')
# ('What mode of transportation do you use to get to the gym ON campus? CHECK ALL THAT APPLY [Tues, Thurs]', 'transportation_tth_on_campus')
# ('What mode of transportation do you use to get to the gym ON campus? CHECK ALL THAT APPLY [Weekend]', 'transportation_ss_on_campus')
# ('Approximately how many times do you walk/bike/etc pass an ON campus gym each day? ONE ANSWER PER ROW [Mon, Wed, Fri]', 'mwf_passing_gym')
# ('Approximately how many times do you walk/bike/etc pass an ON campus gym each day? ONE ANSWER PER ROW [Tues, Thurs]', 'tth_passing_gym')
# ('Approximately how many times do you walk/bike/etc pass an ON campus gym each day? ONE ANSWER PER ROW [Weekend]', 'ss_passing_gym')
# ('If you go to the gym ON campus, which one do you go to the most often?', 'main_gym_location')
# ('If you go to the gym ON campus, which one(s) do you go to in general? CHECK ALL THAT APPLY', 'gen_gym_locations')
# ('Rank your reasons for choosing the gym you attend the most over the others (1 being least important reason, 7 being the most important reason). You can only use each number once. [How close you are to the gym]', 'proximity_importance')
# ('Rank your reasons for choosing the gym you attend the most over the others (1 being least important reason, 7 being the most important reason). You can only use each number once. [Equipment offered]', 'equipment_importance')
# ('Rank your reasons for choosing the gym you attend the most over the others (1 being least important reason, 7 being the most important reason). You can only use each number once. [Hours of operation]', 'time_importance')
# ('Rank your reasons for choosing the gym you attend the most over the others (1 being least important reason, 7 being the most important reason). You can only use each number once. [Taking a rec class]', 'class_importance')
# ('Rank your reasons for choosing the gym you attend the most over the others (1 being least important reason, 7 being the most important reason). You can only use each number once. [Friends go there]', 'friends_importance')
# ('Rank your reasons for choosing the gym you attend the most over the others (1 being least important reason, 7 being the most important reason). You can only use each number once. [Student Athlete (practicing for a sport)]', 'student_athlete_importance')
# ('Rank your reasons for choosing the gym you attend the most over the others (1 being least important reason, 7 being the most important reason). You can only use each number once. [Other]', 'other_importance')
# ("What's your main motivator for going to the gym?", 'main_motivator')
# ('What times of the day do you normally go to the gym? CHECK ALL THAT APPLY.', 'attend_gym_times')
# ("What's your UCSD email?", 'email')

# %%
df.columns = rename_columns
df
# Out:
#          time_submitted                location  \
# 0    5/14/2019 23:58:03                 Revelle
# 1     5/15/2019 0:16:33                Marshall
# 2     5/15/2019 0:26:17                    Muir
# 3     5/15/2019 0:31:37  I don't live on campus
# 4     5/15/2019 0:35:18                Marshall
# 5     5/15/2019 0:37:27  I don't live on campus
# 6     5/15/2019 0:37:55  I don't live on campus
# 7     5/15/2019 0:44:34  I don't live on campus
# 8     5/15/2019 1:01:20  I don't live on campus
# 9     5/15/2019 1:01:58  I don't live on campus
# 10    5/15/2019 1:05:29  I don't live on campus
# 11    5/15/2019 1:13:14  I don't live on campus
# 12    5/15/2019 1:52:09                 Revelle
# 13    5/15/2019 2:08:38                 Revelle
# 14    5/15/2019 2:22:46  I don't live on campus
# 15    5/15/2019 3:09:13                 Revelle
# 16    5/15/2019 3:26:32  I don't live on campus
# 17    5/15/2019 4:28:24                   Sixth
# 18    5/15/2019 4:29:03                 Revelle
# 19    5/15/2019 4:29:18                      IG
# 20    5/15/2019 4:37:37                Marshall
# 21    5/15/2019 4:48:44                Marshall
# 22    5/15/2019 5:10:23                     ERC
# 23    5/15/2019 5:20:36                  Warren
# 24    5/15/2019 5:28:11  I don't live on campus
# 25    5/15/2019 5:38:57  I don't live on campus
# 26    5/15/2019 6:04:13                Marshall
# 27    5/15/2019 6:10:19  I don't live on campus
# 28    5/15/2019 6:17:31                  Warren
# 29    5/15/2019 6:23:37  I don't live on campus
# ..                  ...                     ...
# 90   5/16/2019 23:52:39                  Warren
# 91    5/17/2019 2:11:48                  Warren
# 92    5/17/2019 3:15:10                    Muir
# 93    5/17/2019 3:42:05                Marshall
# 94    5/17/2019 5:01:39             The Village
# 95    5/17/2019 6:52:13             The Village
# 96    5/17/2019 7:29:07  I don't live on campus
# 97    5/17/2019 7:43:19                Marshall
# 98    5/17/2019 8:46:10                  Warren
# 99    5/17/2019 9:06:28                     ERC
# 100  5/17/2019 18:00:42  I don't live on campus
# 101  5/17/2019 18:57:41                     ERC
# 102  5/17/2019 19:08:22  I don't live on campus
# 103  5/17/2019 23:53:16                   Sixth
# 104   5/18/2019 2:20:44                  Warren
# 105   5/18/2019 5:20:22  I don't live on campus
# 106   5/18/2019 5:51:15  I don't live on campus
# 107  5/19/2019 21:40:18                   Sixth
# 108  5/19/2019 21:59:57                   Sixth
# 109  5/19/2019 22:36:32  I don't live on campus
# 110   5/20/2019 0:21:10                   Sixth
# 111   5/20/2019 5:39:46                   Sixth
# 112  5/20/2019 21:34:28                    Muir
# 113  5/20/2019 22:40:46                    Muir
# 114   5/21/2019 1:13:49                    Muir
# 115   5/21/2019 5:24:54                    Muir
# 116  5/21/2019 14:35:50                    Muir
# 117  5/21/2019 22:56:08  I don't live on campus
# 118  5/22/2019 21:15:07                    Muir
# 119   5/23/2019 6:06:48                  Warren
#
#                                                  major  \
# 0                              Physiology&Neuroscience
# 1                 Ecology Behavior and Evolution (EBE)
# 2                              Human Health Psychology
# 3                                            Human Bio
# 4                                        Human Biology
# 5                                        Human Biology
# 6                                 Chemical Engineering
# 7                                                  EBE
# 8                                        public health
# 9                                         Biochem/Chem
# 10                                     NanoEngineering
# 11                                                cogs
# 12                                 Business Psychology
# 13                                  Mechanic Engineer
# 14                                      Marine Biology
# 15                           Cell Biology/Biochemistry
# 16                                              Cogsci
# 17                                   Molecular Biology
# 18                                          Psychology
# 19                                          Phys/Neuro
# 20                                    Computer Science
# 21                                       Human Biology
# 22                               Int'l Stud - Poli Sci
# 23                                      Human Biology
# 24                                       Human biology
# 25                                         Psychology
# 26                                     General Biology
# 27                                   Human Development
# 28                         Bioengineering: biosystems
# 29                              Biochemistry/Chemistry
# ..                                                 ...
# 90                            Biology: bioinformatics
# 91                                             Math-CS
# 92                                    Computer Science
# 93                                     General Biology
# 94                                       Communucation
# 95                                    Computer Science
# 96                                            Cogs sci
# 97                                          Psychology
# 98                                    Computer Science
# 99                                      Bioengineering
# 100                                      Human Biology
# 101                                     Marine Biology
# 102                                     Human Biology
# 103         CogSci w/ a Specialization in Neuroscience
# 104                                     Human biology
# 105        Human Developmental Sciences and Psychology
# 106                                   Computer Science
# 107                  Mathematics/ Secondary Education
# 108                               Chemical Engineering
# 109  Cognitive and Behavioral Neuroscience and Busi...
# 110                                            History
# 111                             Mechanical Engineering
# 112                            Structural Engineering
# 113                                       Neurobiology
# 114  Environmental Systems: Ecology, Behavior, and ...
# 115                               Clinical Psychology
# 116                                     Human biology
# 117                      Ecology, Behavior & Evolution
# 118                                              psych
# 119                                  Cognitive Science
#
#                                    curr_activity_level  \
# 0    Contemplation - currently not doing exercise, ...
# 1    Contemplation - currently not doing exercise, ...
# 2    Contemplation - currently not doing exercise, ...
# 3       Preparation - doing exercise but not regularly
# 4    Contemplation - currently not doing exercise, ...
# 5    Priority - intensive exercise multiple times a...
# 6    Contemplation - currently not doing exercise, ...
# 7    Priority - intensive exercise multiple times a...
# 8    Contemplation - currently not doing exercise, ...
# 9    Maintenance - regularly exercising for 6 month...
# 10   Priority - intensive exercise multiple times a...
# 11   Contemplation - currently not doing exercise, ...
# 12   Contemplation - currently not doing exercise, ...
# 13   Maintenance - regularly exercising for 6 month...
# 14      Preparation - doing exercise but not regularly
# 15   Precontemplation - currently not doing exercis...
# 16   Priority - intensive exercise multiple times a...
# 17   Action - regularly exercise but for less than ...
# 18   Maintenance - regularly exercising for 6 month...
# 19   Priority - intensive exercise multiple times a...
# 20   Maintenance - regularly exercising for 6 month...
# 21   Maintenance - regularly exercising for 6 month...
# 22   Priority - intensive exercise multiple times a...
# 23   Priority - intensive exercise multiple times a...
# 24   Maintenance - regularly exercising for 6 month...
# 25   Action - regularly exercise but for less than ...
# 26   Precontemplation - currently not doing exercis...
# 27      Preparation - doing exercise but not regularly
# 28   Maintenance - regularly exercising for 6 month...
# 29   Priority - intensive exercise multiple times a...
# ..                                                 ...
# 90   Maintenance - regularly exercising for 6 month...
# 91   Maintenance - regularly exercising for 6 month...
# 92   Contemplation - currently not doing exercise, ...
# 93      Preparation - doing exercise but not regularly
# 94   Contemplation - currently not doing exercise, ...
# 95   Priority - intensive exercise multiple times a...
# 96      Preparation - doing exercise but not regularly
# 97      Preparation - doing exercise but not regularly
# 98      Preparation - doing exercise but not regularly
# 99   Priority - intensive exercise multiple times a...
# 100     Preparation - doing exercise but not regularly
# 101     Preparation - doing exercise but not regularly
# 102  Priority - intensive exercise multiple times a...
# 103  Contemplation - currently not doing exercise, ...
# 104  Action - regularly exercise but for less than ...
# 105  Contemplation - currently not doing exercise, ...
# 106  Priority - intensive exercise multiple times a...
# 107  Priority - intensive exercise multiple times a...
# 108     Preparation - doing exercise but not regularly
# 109     Preparation - doing exercise but not regularly
# 110     Preparation - doing exercise but not regularly
# 111     Preparation - doing exercise but not regularly
# 112  Priority - intensive exercise multiple times a...
# 113     Preparation - doing exercise but not regularly
# 114     Preparation - doing exercise but not regularly
# 115  Maintenance - regularly exercising for 6 month...
# 116  Action - regularly exercise but for less than ...
# 117  Maintenance - regularly exercising for 6 month...
# 118  Priority - intensive exercise multiple times a...
# 119     Preparation - doing exercise but not regularly
#
#                                    past_activity_level  exercise_importance  \
# 0    Contemplation - did not exercise but intended ...                    4
# 1                 Preparation - exercised infrequently                    6
# 2    Maintenance - regularly exercising for 6 month...                    7
# 3    Maintenance - regularly exercising for 6 month...                    8
# 4    Action - regularly exercised but for less than...                    8
# 5           Precontemplation - did not exercise at all                    8
# 6                 Preparation - exercised infrequently                    5
# 7    Maintenance - regularly exercising for 6 month...                    8
# 8                 Preparation - exercised infrequently                    7
# 9                 Preparation - exercised infrequently                    7
# 10   Maintenance - regularly exercising for 6 month...                    9
# 11   Contemplation - did not exercise but intended ...                    3
# 12                Preparation - exercised infrequently                    8
# 13   Priority - intensive exercise multiple times a...                    8
# 14   Maintenance - regularly exercising for 6 month...                    8
# 15          Precontemplation - did not exercise at all                    1
# 16   Maintenance - regularly exercising for 6 month...                   10
# 17                Preparation - exercised infrequently                    9
# 18   Priority - intensive exercise multiple times a...                   10
# 19   Priority - intensive exercise multiple times a...                   10
# 20   Priority - intensive exercise multiple times a...                    8
# 21   Maintenance - regularly exercising for 6 month...                    9
# 22                Preparation - exercised infrequently                    7
# 23   Priority - intensive exercise multiple times a...                    9
# 24   Maintenance - regularly exercising for 6 month...                    5
# 25   Maintenance - regularly exercising for 6 month...                    7
# 26   Contemplation - did not exercise but intended ...                    5
# 27   Maintenance - regularly exercising for 6 month...                    6
# 28   Maintenance - regularly exercising for 6 month...                    8
# 29          Precontemplation - did not exercise at all                    9
# ..                                                 ...                  ...
# 90   Action - regularly exercised but for less than...                   10
# 91   Priority - intensive exercise multiple times a...                   10
# 92   Contemplation - did not exercise but intended ...                    6
# 93   Maintenance - regularly exercising for 6 month...                    6
# 94   Action - regularly exercised but for less than...                    4
# 95   Maintenance - regularly exercising for 6 month...                   10
# 96   Maintenance - regularly exercising for 6 month...                    4
# 97   Action - regularly exercised but for less than...                    3
# 98                Preparation - exercised infrequently                    7
# 99   Priority - intensive exercise multiple times a...                   10
# 100  Maintenance - regularly exercising for 6 month...                    4
# 101  Priority - intensive exercise multiple times a...                    8
# 102  Priority - intensive exercise multiple times a...                    8
# 103               Preparation - exercised infrequently                    7
# 104               Preparation - exercised infrequently                    8
# 105         Precontemplation - did not exercise at all                    4
# 106  Action - regularly exercised but for less than...                    9
# 107  Priority - intensive exercise multiple times a...                    9
# 108  Contemplation - did not exercise but intended ...                    4
# 109  Contemplation - did not exercise but intended ...                    6
# 110  Maintenance - regularly exercising for 6 month...                    8
# 111         Precontemplation - did not exercise at all                    4
# 112  Maintenance - regularly exercising for 6 month...                    8
# 113  Maintenance - regularly exercising for 6 month...                    4
# 114  Maintenance - regularly exercising for 6 month...                    7
# 115  Maintenance - regularly exercising for 6 month...                    8
# 116  Maintenance - regularly exercising for 6 month...                    8
# 117  Maintenance - regularly exercising for 6 month...                   10
# 118  Contemplation - did not exercise but intended ...                    9
# 119  Contemplation - did not exercise but intended ...                    7
#
#                             prior_athlete  \
# 0                                      No
# 1                     Yes, in high school
# 2                     Yes, in high school
# 3                     Yes, in high school
# 4                                      No
# 5    Yes, in high school, Yes, in college
# 6                                      No
# 7                                      No
# 8                     Yes, in high school
# 9    Yes, in high school, Yes, in college
# 10   Yes, in high school, Yes, in college
# 11                                     No
# 12                                     No
# 13   Yes, in high school, Yes, in college
# 14                        Yes, in college
# 15                                     No
# 16   Yes, in high school, Yes, in college
# 17                    Yes, in high school
# 18                    Yes, in high school
# 19   Yes, in high school, Yes, in college
# 20   Yes, in high school, Yes, in college
# 21   Yes, in high school, Yes, in college
# 22                                     No
# 23   Yes, in high school, Yes, in college
# 24   Yes, in high school, Yes, in college
# 25                    Yes, in high school
# 26                                     No
# 27   Yes, in high school, Yes, in college
# 28                    Yes, in high school
# 29                                     No
# ..                                    ...
# 90                    Yes, in high school
# 91   Yes, in high school, Yes, in college
# 92                                     No
# 93                    Yes, in high school
# 94                                     No
# 95                    Yes, in high school
# 96                    Yes, in high school
# 97                                     No
# 98                                     No
# 99                    Yes, in high school
# 100                   Yes, in high school
# 101                   Yes, in high school
# 102                   Yes, in high school
# 103                   Yes, in high school
# 104  Yes, in high school, Yes, in college
# 105                                    No
# 106                   Yes, in high school
# 107                   Yes, in high school
# 108                                    No
# 109                                    No
# 110  Yes, in high school, Yes, in college
# 111                                    No
# 112                   Yes, in high school
# 113                   Yes, in high school
# 114                                    No
# 115  Yes, in high school, Yes, in college
# 116                   Yes, in high school
# 117  Yes, in high school, Yes, in college
# 118  Yes, in high school, Yes, in college
# 119                   Yes, in high school
#
#                                          sport_history  \
# 0                                                  NaN
# 1                        Swim team and track and field
# 2                                          Color guard
# 3                                        Vball, soccer
# 4                                                  NaN
# 5    Water Polo/Swim in High School, Dragon Boat in...
# 6                                                  NaN
# 7                                                  NaN
# 8                                               tennis
# 9                                 Wrestling, Jiu Jitsu
# 10                                       Rowing, Rugby
# 11                                                 NaN
# 12                                                 NaN
# 13                                          Water polo
# 14                                      Snowboard Team
# 15                                                 NaN
# 16                                              Soccer
# 17                                            Swimming
# 18                           Volleyball, Track, Soccer
# 19   Track in HS. Powerlifting and some volleyball ...
# 20                               Volleyball, badminton
# 21                                          Volleyball
# 22                                                 NaN
# 23   Cross Country, track and field, rock climbing,...
# 24                                               Rugby
# 25                                                Swim
# 26                                                 NaN
# 27                                              Soccer
# 28                      Basketball, tennis, volleyball
# 29                                                 NaN
# ..                                                 ...
# 90                   Volleyball, basketball, badminton
# 91           Cross Country, Track and Field, Badminton
# 92                                                 NaN
# 93                                            Swimming
# 94                                                 NaN
# 95                                              Tennis
# 96                                Competitive dancing
# 97                                                 NaN
# 98                                                 NaN
# 99                                     Track, Football
# 100                                               Swim
# 101                       Cross Country, Track & Field
# 102                        Basketball, Track and Field
# 103                                          Badminton
# 104     Soccer, marching band, dance team, water polo
# 105                                                NaN
# 106                                             Tennis
# 107                                             Soccer
# 108                                                NaN
# 109                                                NaN
# 110                                    Tennis, Cricket
# 111                                                NaN
# 112                                         Wrestling
# 113                           cheerleading, gymnastics
# 114                                                NaN
# 115  Track and Field, cross country, soccer, ballet...
# 116                                 Swim, golf, dance
# 117                            Water Polo and Swimming
# 118                                             dancer
# 119                     Swimming, Track, Cross Country
#
#                                     exercise_locations  \
# 0    At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 1    At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 2    At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 3                                           Off Campus
# 4    At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 5    At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 6                                           Off Campus
# 7              Off Campus, Sports (IM, Club, Division)
# 8    At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 9    At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 10   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 11   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 12   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 13   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 14   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 15                                                 NaN
# 16   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 17   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 18   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 19   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 20   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 21   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 22   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 23                     Outside (on campus), Off Campus
# 24   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 25   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 26                                                 NaN
# 27             Off Campus, Sports (IM, Club, Division)
# 28   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 29   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# ..                                                 ...
# 90   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 91   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 92                                                 NaN
# 93   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 94   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 95   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 96                                          Off Campus
# 97   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 98   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 99   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 100  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 101  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 102  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 103  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 104  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 105  Inside the Residential Halls/Apartments, Off C...
# 106  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 107  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 108  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 109  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 110  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 111  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 112  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 113  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 114  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 115  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 116  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 117  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 118  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 119  At an on campus gym (Main Gym, RIMAC, Spanos, ...
#
#           off_campus_gym_freq  ... proximity_importance equipment_importance  \
# 0                         NaN  ...                  7.0                  5.0
# 1                         NaN  ...                  7.0                  5.0
# 2                         NaN  ...                  7.0                  6.0
# 3         1 or 2 times a week  ...                  7.0                  6.0
# 4                         NaN  ...                  1.0                  5.0
# 5                       Never  ...                  5.0                  7.0
# 6                       Never  ...                  7.0                  3.0
# 7         3 or 4 times a week  ...                  5.0                  3.0
# 8                       Never  ...                  5.0                  7.0
# 9         1 or 2 times a week  ...                  3.0                  5.0
# 10        1 or 2 times a week  ...                  5.0                  7.0
# 11                      Never  ...                  4.0                  5.0
# 12                        NaN  ...                  4.0                  5.0
# 13                        NaN  ...                  7.0                  6.0
# 14      Less than once a week  ...                  7.0                  6.0
# 15                        NaN  ...                  7.0                  5.0
# 16     Less than once a month  ...                  NaN                  NaN
# 17                        NaN  ...                  5.0                  7.0
# 18                        NaN  ...                  5.0                  2.0
# 19                      Never  ...                  3.0                  6.0
# 20                        NaN  ...                  5.0                  2.0
# 21                        NaN  ...                  7.0                  6.0
# 22                        NaN  ...                  7.0                  5.0
# 23                        NaN  ...                  4.0                  7.0
# 24                      Never  ...                  2.0                  6.0
# 25      Less than once a week  ...                  3.0                  6.0
# 26                        NaN  ...                  7.0                  6.0
# 27     Less than once a month  ...                  7.0                  3.0
# 28                        NaN  ...                  7.0                  6.0
# 29   More than 5 times a week  ...                  7.0                  5.0
# ..                        ...  ...                  ...                  ...
# 90                        NaN  ...                  7.0                  6.0
# 91                        NaN  ...                  3.0                  4.0
# 92                        NaN  ...                  NaN                  NaN
# 93                        NaN  ...                  7.0                  5.0
# 94                        NaN  ...                  7.0                  3.0
# 95                        NaN  ...                  1.0                  6.0
# 96        1 or 2 times a week  ...                  7.0                  3.0
# 97                        NaN  ...                  6.0                  3.0
# 98                        NaN  ...                  7.0                  5.0
# 99                        NaN  ...                  NaN                  NaN
# 100                     Never  ...                  4.0                  7.0
# 101                       NaN  ...                  7.0                  5.0
# 102  More than 5 times a week  ...                  5.0                  7.0
# 103                       NaN  ...                  7.0                  6.0
# 104                       NaN  ...                  1.0                  3.0
# 105                     Never  ...                  7.0                  6.0
# 106       3 or 4 times a week  ...                  4.0                  7.0
# 107                       NaN  ...                  1.0                  7.0
# 108                       NaN  ...                  7.0                  6.0
# 109    Less than once a month  ...                  4.0                  5.0
# 110                       NaN  ...                  1.0                  7.0
# 111                       NaN  ...                  4.0                  6.0
# 112                       NaN  ...                  6.0                  7.0
# 113                       NaN  ...                  3.0                  5.0
# 114                       NaN  ...                  1.0                  2.0
# 115                       NaN  ...                  5.0                  6.0
# 116                       NaN  ...                  6.0                  7.0
# 117                     Never  ...                  1.0                  3.0
# 118                       NaN  ...                  2.0                  7.0
# 119                       NaN  ...                  NaN                  7.0
#
#     time_importance class_importance friends_importance  \
# 0               6.0              2.0                3.0
# 1               4.0              1.0                6.0
# 2               4.0              2.0                5.0
# 3               4.0              5.0                3.0
# 4               2.0              6.0                4.0
# 5               6.0              4.0                2.0
# 6               5.0              4.0                2.0
# 7               4.0              7.0                2.0
# 8               6.0              1.0                4.0
# 9               4.0              1.0                7.0
# 10              6.0              2.0                3.0
# 11              3.0              7.0                6.0
# 12              6.0              3.0                2.0
# 13              5.0              4.0                2.0
# 14              5.0              1.0                4.0
# 15              4.0              3.0                6.0
# 16              NaN              NaN                NaN
# 17              6.0              2.0                4.0
# 18              7.0              3.0                4.0
# 19              7.0              1.0                4.0
# 20              3.0              4.0                6.0
# 21              5.0              1.0                2.0
# 22              6.0              1.0                2.0
# 23              5.0              1.0                3.0
# 24              4.0              1.0                7.0
# 25              2.0              1.0                NaN
# 26              5.0              2.0                4.0
# 27              6.0              1.0                2.0
# 28              2.0              5.0                4.0
# 29              6.0              1.0                4.0
# ..              ...              ...                ...
# 90              2.0              4.0                5.0
# 91              5.0              1.0                6.0
# 92              NaN              NaN                NaN
# 93              6.0              2.0                4.0
# 94              4.0              1.0                6.0
# 95              2.0              3.0                4.0
# 96              6.0              1.0                5.0
# 97              5.0              1.0                4.0
# 98              3.0              4.0                6.0
# 99              NaN              NaN                NaN
# 100             6.0              5.0                3.0
# 101             3.0              4.0                6.0
# 102             6.0              1.0                3.0
# 103             5.0              1.0                2.0
# 104             2.0              7.0                6.0
# 105             4.0              3.0                5.0
# 106             6.0              5.0                3.0
# 107             6.0              3.0                5.0
# 108             4.0              2.0                5.0
# 109             3.0              2.0                6.0
# 110             3.0              2.0                6.0
# 111             7.0              2.0                5.0
# 112             5.0              4.0                3.0
# 113             2.0              NaN                6.0
# 114             3.0              7.0                4.0
# 115             4.0              3.0                2.0
# 116             4.0              2.0                5.0
# 117             2.0              4.0                6.0
# 118             6.0              1.0                3.0
# 119             6.0              NaN                NaN
#
#     student_athlete_importance other_importance  \
# 0                          1.0              4.0
# 1                          2.0              3.0
# 2                          1.0              NaN
# 3                          1.0              2.0
# 4                          7.0              3.0
# 5                          3.0              1.0
# 6                          1.0              6.0
# 7                          1.0              6.0
# 8                          3.0              2.0
# 9                          6.0              2.0
# 10                         4.0              1.0
# 11                         1.0              2.0
# 12                         1.0              7.0
# 13                         3.0              1.0
# 14                         3.0              2.0
# 15                         2.0              1.0
# 16                         7.0              NaN
# 17                         1.0              3.0
# 18                         6.0              1.0
# 19                         2.0              5.0
# 20                         7.0              NaN
# 21                         4.0              3.0
# 22                         3.0              4.0
# 23                         6.0              2.0
# 24                         5.0              3.0
# 25                         7.0              5.0
# 26                         1.0              3.0
# 27                         5.0              4.0
# 28                         1.0              3.0
# 29                         2.0              3.0
# ..                         ...              ...
# 90                         3.0              1.0
# 91                         7.0              2.0
# 92                         NaN              NaN
# 93                         1.0              3.0
# 94                         2.0              5.0
# 95                         5.0              NaN
# 96                         4.0              2.0
# 97                         2.0              7.0
# 98                         2.0              1.0
# 99                         NaN              NaN
# 100                        1.0              2.0
# 101                        1.0              2.0
# 102                        2.0              4.0
# 103                        4.0              3.0
# 104                        4.0              5.0
# 105                        1.0              2.0
# 106                        2.0              1.0
# 107                        2.0              4.0
# 108                        1.0              3.0
# 109                        1.0              7.0
# 110                        4.0              5.0
# 111                        1.0              3.0
# 112                        1.0              2.0
# 113                        1.0              4.0
# 114                        6.0              5.0
# 115                        7.0              1.0
# 116                        1.0              3.0
# 117                        7.0              5.0
# 118                        4.0              5.0
# 119                        NaN              NaN
#
#                                         main_motivator  \
# 0              to feel better emotionally & physically
# 1                                        to be healthy
# 2                      Being healthy and losing weight
# 3                                                  NaN
# 4                                     Maintain health
# 5                        Get Stronger/better physique
# 6                               I don't go to the gym.
# 7                                                  NaN
# 8                                   health, body image
# 9                                  Fitness/Competition
# 10                                       It's my hobby
# 11                                                 NaN
# 12                         My body appearance / weight
# 13                                         Getting fit
# 14                        Feeling healthy and in shape
# 15                                                 NaN
# 16                                                 NaN
# 17   Staying active is an important part of my life...
# 18                                                 NaN
# 19                 We tryna get thiccer than a Snicker
# 20   v o l l e y b a l l all day everyday if i coul...
# 21                                                 NaN
# 22                                             routine
# 23   Keeping my body healthy! It's the only one you...
# 24                          Bitches, money, icy gainz
# 25                   To clear my mind and stay healthy
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                   Building muscle, powerlifting PRs
# ..                                                 ...
# 90                             To be healthy :) #gains
# 91                       TO GET SWOLE and maintain abs
# 92                                                 NaN
# 93                                        Weight loss
# 94                                                 NaN
# 95                                                 Abs
# 96                             not sit around all day
# 97                                 to have better legs
# 98                                          get STRONG
# 99                                                 NaN
# 100                                                NaN
# 101                     Stress relief/ general health
# 102                                      Bodybuilding
# 103                                            Fitness
# 104                                            Health
# 105  To take care of my body as the temple of the H...
# 106                  I'm trying to improve my physique
# 107           Healthy Lifestyle ( Mental and Physical)
# 108        Convenience - being close inbetween classes
# 109  To get stronger/going with my friend to keep m...
# 110                      Want to get into better shape
# 111                                      being healthy
# 112                                             Health
# 113                                  just to be active
# 114                     Working out makes me feel good
# 115                                        Staying fit
# 116                                    Health/wellness
# 117                                           Fit Body
# 118  I was a skinny queen before college and I gain...
# 119                                                NaN
#
#                                       attend_gym_times               email
# 0          Evening (4PM - 7PM), I don't go to the gym.   jrgruver@ucsd.edu
# 1    Evening (4PM - 7PM), Night (8PM - 12AM), I don...   lcarlson@ucsd.edu
# 2              Evening (4PM - 7PM), Night (8PM - 12AM)    lmaraan@ucsd.edu
# 3    Late Morning (9AM - 11AM), Afternoon (12PM - 3...      morel@ucsd.edu
# 4          Afternoon (12PM - 3PM), Evening (4PM - 7PM)     cjt025@ucsd.edu
# 5    Late Morning (9AM - 11AM), Afternoon (12PM - 3...     ringle@ucsd.edu
# 6                               I don't go to the gym.     jas139@ucsd.edu
# 7                                  Evening (4PM - 7PM)                 NaN
# 8           Night (8PM - 12AM), I don't go to the gym.     p9phan@ucsd.edu
# 9       Early Morning (4AM - 8AM), Evening (4PM - 7PM)     ajr062@ucsd.edu
# 10         Afternoon (12PM - 3PM), Evening (4PM - 7PM)     ajs021@ucsd.edu
# 11             Evening (4PM - 7PM), Night (8PM - 12AM)     naskar@ucsd.edu
# 12                           Late Morning (9AM - 11AM)    vatsang@ucsd.edu
# 13       Late Morning (9AM - 11AM), Night (8PM - 12AM)    llumada@ucsd.edu
# 14                           Late Morning (9AM - 11AM)   hrhoffma@ucsd.edu
# 15                              I don't go to the gym.                 NaN
# 16   Early Morning (4AM - 8AM), Late Morning (9AM -...     amr052@ucsd.edu
# 17             Evening (4PM - 7PM), Night (8PM - 12AM)     whgong@ucsd.edu
# 18             Evening (4PM - 7PM), Night (8PM - 12AM)     c3chin@ucsd.edu
# 19   Afternoon (12PM - 3PM), Evening (4PM - 7PM), N...     chl651@ucsd.edu
# 20   Afternoon (12PM - 3PM), Evening (4PM - 7PM), N...      skwan@ucsd.edu
# 21   Late Morning (9AM - 11AM), Afternoon (12PM - 3...     lax004@ucsd.edu
# 22   Late Morning (9AM - 11AM), Afternoon (12PM - 3...                 NaN
# 23   Late Morning (9AM - 11AM), Evening (4PM - 7PM)...     kpl009@ucsd.edu
# 24   Late Morning (9AM - 11AM), Afternoon (12PM - 3PM)                 NaN
# 25             Evening (4PM - 7PM), Night (8PM - 12AM)       Ddun@ucsd.edu
# 26                              I don't go to the gym.     jtn051@ucsd.edu
# 27                                 Evening (4PM - 7PM)   Mdaruval@ucsd.edu
# 28         Afternoon (12PM - 3PM), Evening (4PM - 7PM)                 NaN
# 29       Early Morning (4AM - 8AM), Night (8PM - 12AM)     tcn001@ucsd.edu
# ..                                                 ...                 ...
# 90                           Late Morning (9AM - 11AM)     mml053@ucsd.edu
# 91             Evening (4PM - 7PM), Night (8PM - 12AM)      p3tan@ucsd.edu
# 92                              I don't go to the gym.    akjalan@ucsd.edu
# 93                                  Night (8PM - 12AM)     Ammoya@ucsd.edu
# 94                              I don't go to the gym.    krtsang@ucsd.edu
# 95                                  Night (8PM - 12AM)      Tzqin@ucsd.edu
# 96   Late Morning (9AM - 11AM), Afternoon (12PM - 3PM)  Bcvargas@ucsd.edu
# 97                              Afternoon (12PM - 3PM)     hal419@ucsd.edu
# 98       Late Morning (9AM - 11AM), Night (8PM - 12AM)   dverzhbi@ucsd.edu
# 99                                  Night (8PM - 12AM)   blawrenc@ucsd.edu
# 100                          Late Morning (9AM - 11AM)     aljiao@ucsd.edu
# 101     Late Morning (9AM - 11AM), Evening (4PM - 7PM)   chdonald@ucsd.edu
# 102        Afternoon (12PM - 3PM), Evening (4PM - 7PM)   Bmiramon@ucsd.edu
# 103            Evening (4PM - 7PM), Night (8PM - 12AM)     ssl104@ucsd.edu
# 104                                 Night (8PM - 12AM)    nsverma@ucsd.edu
# 105                                Evening (4PM - 7PM)     vac008@ucsd.edu
# 106     Late Morning (9AM - 11AM), Evening (4PM - 7PM)    lnathan@ucsd.edu
# 107            Evening (4PM - 7PM), Night (8PM - 12AM)    epruett@ucsd.edu
# 108                             Afternoon (12PM - 3PM)   btheirin@ucsd.edu
# 109                          Late Morning (9AM - 11AM)   dhowanec@ucsd.edu
# 110                                Evening (4PM - 7PM)      onrao@ucsd.edu
# 111  Afternoon (12PM - 3PM), Evening (4PM - 7PM), N...     b4tang@ucsd.edu
# 112         Afternoon (12PM - 3PM), Night (8PM - 12AM)   Mamoctez@ucsd.edu
# 113        Afternoon (12PM - 3PM), Evening (4PM - 7PM)    srmajor@ucsd.edu
# 114            Evening (4PM - 7PM), Night (8PM - 12AM)   kkornher@ucsd.edu
# 115                                 Night (8PM - 12AM)   schavezm@ucsd.edu
# 116                             Afternoon (12PM - 3PM)   Mdermont@ucsd.edu
# 117            Evening (4PM - 7PM), Night (8PM - 12AM)    mrafter@ucsd.edu
# 118  Afternoon (12PM - 3PM), Evening (4PM - 7PM), N...   kvenegas@ucsd.edu
# 119                                Evening (4PM - 7PM)                 NaN
#
# [120 rows x 44 columns]

# %% [markdown]
# Clean majors into different categories (STEM, Humanities, and Social Science)

# %%
'''
Categorizes majors into:
    - STEM: Science, Technology, Engineering, and Math
    - HUM: Humanities
    - SS: Social Science
    - OTH: Other (undeclared)
'''

def clean_job (title):
    title = title.lower()
    title = title.strip()
    
    stem = ['computer science', 'human bio', 'ebe', 'chem', 'biology', 'engineer', 'cog',
            'neuro', 'computer ascience', 'cbn', 'cs', 'math', 'ecology', 'ciomp sci']
    hum = ['icam', 'history']
    ss = ['psych', 'management science', 'public health', 'human development',
          'international business', 'communucation', 'poli sci', 'urban studies']
    
    output = "OTH"
    
    for label in stem:
        if label in title:
            output = "STEM"

    for label in hum:
        if label in title:
            output = "HUM"
        
    for label in ss:
        if label in title:
            output = "SS"
        
    return output

# %%
def clean_on_campus_freq (frequency):
    frequency = frequency.lower()
    frequency = frequency.strip()
    
    if 'never' in frequency:
        output = 0
    elif 'month' in frequency:
        output = 1
    elif '3' in frequency:
        output = 4
    elif '1' in frequency:
        output = 3
    elif 'week' in frequency:
        output = 2
        
    return output

# %%
df['major'] = df['major'].apply(clean_job)
df['on_campus_gym_freq'] = df['on_campus_gym_freq'].apply(clean_on_campus_freq)

# %%
#Noticing the skew in majors... that might be something that we want
#to point out in our data analysis. Not getting representation from
#humanities majors, but also I put cog sci under stem (can be ss or stem)
#and I put public health under ss (can be ss or stem)
df['major'].value_counts()
df['on_campus_gym_freq'].value_counts()
# Out:
# 4    29
# 3    27
# 2    23
# 1    23
# 0    18
# Name: on_campus_gym_freq, dtype: int64

# %% [markdown]
# # Visualizations

# %% [markdown]
# ### Importance vs. On-Campus-Freq

# %%
def drop_no_importance(df):
    importance = df.dropna(subset=["proximity_importance", "equipment_importance", "time_importance", "class_importance",
              "friends_importance", "student_athlete_importance", "other_importance"])
    
    return importance

# %%
importance = drop_no_importance(df)

# %%
fig, axes = plt.subplots(nrows=4, ncols=2,figsize=(20,20))
axes[0][0].scatter(df['proximity_importance'], df['on_campus_gym_freq'], s=80, alpha=0.1)
axes[0][0].set_xlabel("proximity_importance")
axes[0][0].set_ylabel("on_campus_gym_freq")

axes[1][0].scatter(df['equipment_importance'], df['on_campus_gym_freq'], s=80, alpha=0.1)
axes[1][0].set_xlabel("equipment_importance")
axes[1][0].set_ylabel("on_campus_gym_freq")

axes[2][0].scatter(df['time_importance'], df['on_campus_gym_freq'], s=80, alpha=0.1)
axes[2][0].set_xlabel("time_importance")
axes[2][0].set_ylabel("on_campus_gym_freq")

axes[3][0].scatter(df['class_importance'], df['on_campus_gym_freq'], s=80, alpha=0.1)
axes[3][0].set_xlabel("class_importance")
axes[3][0].set_ylabel("on_campus_gym_freq")

axes[0][1].scatter(df['friends_importance'], df['on_campus_gym_freq'], s=80, alpha=0.1)
axes[0][1].set_xlabel("friends_importance")
axes[0][1].set_ylabel("on_campus_gym_freq")

axes[1][1].scatter(df['student_athlete_importance'], df['on_campus_gym_freq'], s=80, alpha=0.1)
axes[1][1].set_xlabel("student_athlete_importance")
axes[1][1].set_ylabel("on_campus_gym_freq")

axes[2][1].scatter(df['other_importance'], df['on_campus_gym_freq'], s=80, alpha=0.1)
axes[2][1].set_xlabel("other_importance")
axes[2][1].set_ylabel("on_campus_gym_freq")

plt.show()

# %% [markdown]
# ### Location vs. On-Campus-Freq

# %%
revelle = df[df['location'] == 'Revelle']
marshall = df[df['location'] == 'Marshall']
muir = df[df['location'] == 'Muir']
warren = df[df['location'] == 'Warren']
sixth = df[df['location'] == 'Sixth']
erc = df[df['location'] == 'ERC']
village = df[df['location'] == 'The Village']
off = df[df['location'] == 'I don\'t live on campus']

# %%
revelle_freq = revelle['on_campus_gym_freq'].mean()
marshall_freq = marshall['on_campus_gym_freq'].mean()
muir_freq = muir['on_campus_gym_freq'].mean()
warren_freq = warren['on_campus_gym_freq'].mean()
sixth_freq = sixth['on_campus_gym_freq'].mean()
erc_freq = erc['on_campus_gym_freq'].mean()
village_freq = village['on_campus_gym_freq'].mean()
off_freq = off['on_campus_gym_freq'].mean()

# %%
location_on_freq = pd.DataFrame({revelle_freq, marshall_freq, muir_freq, warren_freq, erc_freq, village_freq, off_freq})
labels = ('revelle', 'marshall', 'muir', 'warren', 'erc', 'village', 'off')
ax = location_on_freq.plot.bar(rot=0,figsize=(20,10))
y_pos = np.arange(len(labels))
plt.xticks(y_pos, labels)
plt.show()

# %%
print(revelle_freq)
print(marshall_freq)
print(muir_freq)
print(warren_freq)
print(sixth_freq)
print(erc_freq)
print(village_freq)
print(off_freq)
# Out:
# 1.5454545454545454
# 1.9090909090909092
# 2.3636363636363638
# 2.933333333333333
# 2.5833333333333335
# 2.375
# 1.75
# 2.0930232558139537

# %% [markdown]
# ### Commute challenges vs. On-Campus-Freq

# %%
#"commute_challenges_mwf_on_campus", "commute_challenges_tth_on_campus", "commute_challenges_ss_on_campus"
def clean_challenges (row):
    cleaned = ''
    for entry in [row["commute_challenges_mwf_on_campus"], row["commute_challenges_tth_on_campus"],
                  row["commute_challenges_ss_on_campus"]]:
        if entry is np.nan:
            cleaned += 'X'
            continue
        if 'uphill' in entry:
            cleaned += 'U'
        if 'stair' in entry:
            cleaned += 'S'
    return cleaned

# %%
challenge = df
challenge['week_challenge'] = transport.apply(lambda row: clean_challenges(row), axis=1)

# %%
none = challenge[challenge['week_challenge'].str.contains("XXX")]
uphill = challenge[challenge['week_challenge'].str.contains("U")]
stairs = challenge[challenge['week_challenge'].str.contains("S")]

# %%
none_freq = none['on_campus_gym_freq'].mean()
uphill_freq = uphill['on_campus_gym_freq'].mean()
stairs_freq = stairs['on_campus_gym_freq'].mean()

# %%
challenge_on_freq = pd.DataFrame({none_freq, uphill_freq, stairs_freq})
labels = ('none', 'uphill', 'stairs')
ax = challenge_on_freq.plot.bar(rot=0,figsize=(20,10))
y_pos = np.arange(len(labels))
plt.xticks(y_pos, labels)
plt.show()

# %% [markdown]
# ### avg_commute_on_campus vs. on-campus-freq

# %%
def clean_commute(commute):
    if commute is np.nan:
        return 0
    if '25' in commute:
        return 5
    elif '16' in commute:
        return 4
    elif '11' in commute:
        return 3
    elif '6' in commute:
        return 2
    elif '5' in commute:
        return 1

# %%
def avg_commute(row):
    mwf = row['avg_commute_mwf_on_campus']
    tth = row['avg_commute_tth_on_campus']
    ss = row['avg_commute_ss_on_campus']
    week = 3*mwf + 2*tth + 2*ss
    week = week/7
    return week

# %%
df['avg_commute_mwf_on_campus'] = df['avg_commute_mwf_on_campus'].apply(clean_commute)
df['avg_commute_tth_on_campus'] = df['avg_commute_tth_on_campus'].apply(clean_commute)
df['avg_commute_ss_on_campus'] = df['avg_commute_ss_on_campus'].apply(clean_commute)
df['week_commute'] = df.apply(lambda row: avg_commute(row), axis=1)

# %%
plt.scatter(df['week_commute'], df['on_campus_gym_freq'],s=80, alpha=0.1)
plt.xlabel("week_commute")
plt.ylabel("on_campus_gym_freq")
plt.show()

# %% [markdown]
# ### main_gym_locations vs locations

# %%
# Revelle, Muir, Marshall, Warren, ERC, Sixth, The Village
# Main gym, RIMAC, Keeling, Canyon View, Spanos
def distance_correl(row):
    location = row['location']
    gym = row['main_gym_location']
    if (location, gym) in [('The Village', 'Spanos'), ('The Village', 'RIMAC'),
                           ('ERC', 'RIMAC'), ('Revelle', 'Keeling Gym'), ('Warren', 'Canyon View'),
                           ('Muir', 'Main Gym'), ('Marshall', 'Main Gym'), ('Marshall', 'RIMAC')]:
        return 1
    elif (location, gym) in [('Sixth', 'Canyon View'), ('Revelle', 'Main Gym'), ('Muir', 'Keeling Gym'), ('Muir', 'RIMAC'),
                             ('ERC', 'Spanos'), ('ERC', 'Main Gym'), ('Marshall', 'Spanos'), ('The Village', 'Main Gym')]:
        return 2
    elif (location, gym) in [('Warren', 'RIMAC'), ('Revelle', 'RIMAC'), ('Marshall', 'Canyon View'),
                             ('Marshall', 'Keeling Gym'), ('The Village', 'Canyon View')]:
        return 3
    elif (location, gym) in [('Warren', 'Main Gym'), ('Sixth', 'Keeling Gym'), ('ERC', 'Canyon View')]:
        return 4
    else:
        return 5

# %%
df['distance_correl'] = df.apply(lambda row: distance_correl(row), axis=1)
df = df[df['location'] != 'I don\'t live on campus']

# %%
plt.scatter(df['distance_correl'], df['on_campus_gym_freq'],s=80, alpha=0.1)
plt.xlabel("distance_correlation")
plt.ylabel("on_campus_gym_freq")
plt.show()

# %%
plt.scatter(df['distance_correl'], df['proximity_importance'],s=80, alpha=0.1)
plt.xlabel("distance_correlation")
plt.ylabel("proximity_importance")
plt.show()

# %% [markdown]
# ### Passing gyms vs. On campus freq

# %%
def clean_passing(passing):
    
    if '9' in passing:
        output = 5
    elif '5' in passing:
        output = 4
    elif '3' in passing:
        output = 3
    elif '1' in passing:
        output = 1
    elif '0' in passing:
        output = 0
        
    return output

# %%
def avg_passing(row):
    mwf = row['mwf_passing_gym']
    tth = row['tth_passing_gym']
    ss = row['ss_passing_gym']
    week = 3*mwf + 2*tth + 2*ss
    week = week/7
    return week

# %%
df['mwf_passing_gym'] = df['mwf_passing_gym'].apply(clean_passing)
df['tth_passing_gym'] = df['tth_passing_gym'].apply(clean_passing)
df['ss_passing_gym'] = df['ss_passing_gym'].apply(clean_passing)
# Out:
# C:\Users\lebel\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\lebel\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\lebel\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df['week_passing'] = df.apply(lambda row: avg_passing(row), axis=1)
# Out:
# C:\Users\lebel\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.scatter(df['week_passing'], df['on_campus_gym_freq'],s=80, alpha=0.1)
plt.xlabel("week_passing")
plt.ylabel("on_campus_gym_freq")
plt.show()

# %% [markdown]
# ### On campus mode of transportation vs On-campus-freq

# %%
#"transportation_mwf_on_campus", "transportation_tth_on_campus", "transportation_ss_on_campus"
def clean_transport (row):
    cleaned = ''
    for entry in [row["transportation_mwf_on_campus"], row["transportation_tth_on_campus"],
                  row["transportation_ss_on_campus"]]:
        if entry is np.nan:
            cleaned += 'X'
            continue
        if 'Walk' in entry:
            cleaned += 'W'
        if 'Bike' in entry:
            cleaned += 'B'
        if 'Car' in entry:
            cleaned += 'C'
        if 'Skateboard' in entry:
            cleaned += 'K'
        if 'Bus' in entry:
            cleaned += 'S'
    return cleaned

# %%
#transport = df.dropna(subset=["transportation_mwf_on_campus", "transportation_tth_on_campus",
#                              "transportation_ss_on_campus"])
transport = df
transport['week_transport'] = transport.apply(lambda row: clean_transport(row), axis=1)
# Out:
# C:\Users\lebel\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
none = transport[transport['week_transport'].str.contains('XXX')]
walk = transport[transport['week_transport'].str.contains("W")]
bike = transport[transport['week_transport'].str.contains("B")]
car = transport[transport['week_transport'].str.contains("C")]
skateboard = transport[transport['week_transport'].str.contains("K")]
shuttle = transport[transport['week_transport'].str.contains("S")]

# %%
none_freq = none['on_campus_gym_freq'].mean()
walk_freq = walk['on_campus_gym_freq'].mean()
bike_freq = bike['on_campus_gym_freq'].mean()
car_freq = car['on_campus_gym_freq'].mean()
skateboard_freq = skateboard['on_campus_gym_freq'].mean()
shuttle_freq = shuttle['on_campus_gym_freq'].mean()

# %%
transport_on_freq = pd.DataFrame({none_freq, walk_freq, bike_freq, car_freq, skateboard_freq, shuttle_freq})
labels = ('none','walk/jog', 'bike', 'car', 'skateboard', 'shuttle')
ax = transport_on_freq.plot.bar(rot=0,figsize=(20,10))
y_pos = np.arange(len(labels))
plt.xticks(y_pos, labels)
plt.show()

# %% [markdown]
# ### Gen_gym_locations vs On-campus-freq

# %%
def count_gyms(general_gyms):
    if (general_gyms is np.nan):
        return 0
    else:
        count = general_gyms.count(',')
        return count + 1

# %%
gen_gym = df
gen_gym['gen_gym_locations']
gen_gym['number_gyms'] = gen_gym['gen_gym_locations'].apply(count_gyms)
# Out:
# C:\Users\lebel\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
gen_gym['number_gyms'].value_counts()
# Out:
# 1    31
# 2    30
# 3     8
# 0     7
# 4     1
# Name: number_gyms, dtype: int64

# %%
plt.scatter(gen_gym['number_gyms'], gen_gym['on_campus_gym_freq'],s=80, alpha=0.1)
plt.xlabel("number_gyms")
plt.ylabel("on_campus_gym_freq")
plt.show()

# %%
fig, axes = plt.subplots(nrows=4, ncols=2,figsize=(20,20))
axes[0][0].scatter(gen_gym['proximity_importance'], gen_gym['number_gyms'], s=80, alpha=0.1)
axes[0][0].set_xlabel("proximity_importance")
axes[0][0].set_ylabel("number_gyms")

axes[1][0].scatter(gen_gym['equipment_importance'], gen_gym['number_gyms'], s=80, alpha=0.1)
axes[1][0].set_xlabel("equipment_importance")
axes[1][0].set_ylabel("number_gyms")

axes[2][0].scatter(gen_gym['time_importance'], gen_gym['number_gyms'], s=80, alpha=0.1)
axes[2][0].set_xlabel("time_importance")
axes[2][0].set_ylabel("number_gyms")

axes[3][0].scatter(gen_gym['class_importance'], gen_gym['number_gyms'], s=80, alpha=0.1)
axes[3][0].set_xlabel("class_importance")
axes[3][0].set_ylabel("number_gyms")

axes[0][1].scatter(gen_gym['friends_importance'], gen_gym['number_gyms'], s=80, alpha=0.1)
axes[0][1].set_xlabel("friends_importance")
axes[0][1].set_ylabel("number_gyms")

axes[1][1].scatter(gen_gym['student_athlete_importance'], gen_gym['number_gyms'], s=80, alpha=0.1)
axes[1][1].set_xlabel("student_athlete_importance")
axes[1][1].set_ylabel("number_gyms")

axes[2][1].scatter(gen_gym['other_importance'], gen_gym['number_gyms'], s=80, alpha=0.1)
axes[2][1].set_xlabel("other_importance")
axes[2][1].set_ylabel("number_gyms")

plt.show()
