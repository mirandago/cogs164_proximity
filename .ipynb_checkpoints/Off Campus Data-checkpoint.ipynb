# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Questionnaire_Responses.csv")

# %%
df.columns
rename_columns = ["time_submitted", "location", "major", "curr_activity_level", "past_activity_level",
              "exercise_importance", "prior_athlete", "sport_history", "exercise_locations",
              "off_campus_gym_freq", "avg_commute_mwf_off_campus", "avg_commute_tth_off_campus",
              "avg_commute_ss_off_campus", "commute_challenges_mwf_off_campus",
              "commute_challenges_tth_off_campus", "commute_challenges_ss_off_campus",
              "transportation_mwf_off_campus", "transportation_tth_off_campus", "transportation_ss_off_campus",
              "on_campus_gym_freq","avg_commute_mwf_on_campus", "avg_commute_tth_on_campus",
              "avg_commute_ss_on_campus", "commute_challenges_mwf_on_campus",
              "commute_challenges_tth_on_campus", "commute_challenges_ss_on_campus",
              "transportation_mwf_on_campus", "transportation_tth_on_campus", "transportation_ss_on_campus",
              "mwf_passing_gym", "tth_passing_gym", "ss_passing_gym", "main_gym_location","gen_gym_locations",
              "proximity_importance", "equipment_importance", "time_importance", "class_importance",
              "friends_importance", "student_athlete_importance", "other_importance", "main_motivator",
              "attend_gym_times", "email"]
df.columns = rename_columns

# %%
df = df.loc[df['location'] == "I don't live on campus"]

# %%
df
# Out:
#          time_submitted                location  \
# 3     5/15/2019 0:31:37  I don't live on campus
# 5     5/15/2019 0:37:27  I don't live on campus
# 6     5/15/2019 0:37:55  I don't live on campus
# 7     5/15/2019 0:44:34  I don't live on campus
# 8     5/15/2019 1:01:20  I don't live on campus
# 9     5/15/2019 1:01:58  I don't live on campus
# 10    5/15/2019 1:05:29  I don't live on campus
# 11    5/15/2019 1:13:14  I don't live on campus
# 14    5/15/2019 2:22:46  I don't live on campus
# 16    5/15/2019 3:26:32  I don't live on campus
# 24    5/15/2019 5:28:11  I don't live on campus
# 25    5/15/2019 5:38:57  I don't live on campus
# 27    5/15/2019 6:10:19  I don't live on campus
# 29    5/15/2019 6:23:37  I don't live on campus
# 30    5/15/2019 6:39:01  I don't live on campus
# 36    5/15/2019 9:17:35  I don't live on campus
# 40   5/15/2019 18:15:39  I don't live on campus
# 41   5/15/2019 18:28:52  I don't live on campus
# 44   5/15/2019 18:49:27  I don't live on campus
# 45   5/15/2019 19:30:14  I don't live on campus
# 46   5/15/2019 20:52:04  I don't live on campus
# 49   5/15/2019 21:49:53  I don't live on campus
# 50   5/15/2019 22:00:26  I don't live on campus
# 51   5/15/2019 23:22:09  I don't live on campus
# 56    5/16/2019 0:57:14  I don't live on campus
# 65   5/16/2019 17:09:24  I don't live on campus
# 68   5/16/2019 17:27:04  I don't live on campus
# 69   5/16/2019 17:59:40  I don't live on campus
# 74   5/16/2019 18:52:32  I don't live on campus
# 77   5/16/2019 19:15:24  I don't live on campus
# 78   5/16/2019 19:32:28  I don't live on campus
# 81   5/16/2019 20:20:44  I don't live on campus
# 82   5/16/2019 20:29:22  I don't live on campus
# 87   5/16/2019 23:30:07  I don't live on campus
# 88   5/16/2019 23:47:55  I don't live on campus
# 89   5/16/2019 23:48:31  I don't live on campus
# 96    5/17/2019 7:29:07  I don't live on campus
# 100  5/17/2019 18:00:42  I don't live on campus
# 102  5/17/2019 19:08:22  I don't live on campus
# 105   5/18/2019 5:20:22  I don't live on campus
# 106   5/18/2019 5:51:15  I don't live on campus
# 109  5/19/2019 22:36:32  I don't live on campus
# 117  5/21/2019 22:56:08  I don't live on campus
#
#                                                  major  \
# 3                                            Human Bio
# 5                                        Human Biology
# 6                                 Chemical Engineering
# 7                                                  EBE
# 8                                        public health
# 9                                         Biochem/Chem
# 10                                     NanoEngineering
# 11                                                cogs
# 14                                      Marine Biology
# 16                                              Cogsci
# 24                                       Human biology
# 25                                         Psychology
# 27                                   Human Development
# 29                              Biochemistry/Chemistry
# 30                                         cogs + ling
# 36                                       cogsci, music
# 40                                          Psychology
# 41                                    Cog Sci Spec ML
# 44                                Business Psychology
# 45                                       Public Health
# 46                       Bioengineering: Biotechnology
# 49                                          Psychology
# 50                      Bioengineering: Bioinformatics
# 51                                  Human Development
# 56                                                EBE
# 65                                                  CS
# 68                                             math-cs
# 69                                           Human bio
# 74                                  Management Science
# 77                                                ICAM
# 78                            environmental chemistry
# 81                                          Psychology
# 82                                           Human Bio
# 87                                   prefer not to say
# 88                          Biochemistry cell biology
# 89                              Mechanical Engineering
# 96                                            Cogs sci
# 100                                      Human Biology
# 102                                     Human Biology
# 105        Human Developmental Sciences and Psychology
# 106                                   Computer Science
# 109  Cognitive and Behavioral Neuroscience and Busi...
# 117                      Ecology, Behavior & Evolution
#
#                                    curr_activity_level  \
# 3       Preparation - doing exercise but not regularly
# 5    Priority - intensive exercise multiple times a...
# 6    Contemplation - currently not doing exercise, ...
# 7    Priority - intensive exercise multiple times a...
# 8    Contemplation - currently not doing exercise, ...
# 9    Maintenance - regularly exercising for 6 month...
# 10   Priority - intensive exercise multiple times a...
# 11   Contemplation - currently not doing exercise, ...
# 14      Preparation - doing exercise but not regularly
# 16   Priority - intensive exercise multiple times a...
# 24   Maintenance - regularly exercising for 6 month...
# 25   Action - regularly exercise but for less than ...
# 27      Preparation - doing exercise but not regularly
# 29   Priority - intensive exercise multiple times a...
# 30   Action - regularly exercise but for less than ...
# 36   Contemplation - currently not doing exercise, ...
# 40   Priority - intensive exercise multiple times a...
# 41   Priority - intensive exercise multiple times a...
# 44   Action - regularly exercise but for less than ...
# 45   Precontemplation - currently not doing exercis...
# 46   Action - regularly exercise but for less than ...
# 49   Action - regularly exercise but for less than ...
# 50      Preparation - doing exercise but not regularly
# 51   Priority - intensive exercise multiple times a...
# 56   Maintenance - regularly exercising for 6 month...
# 65   Action - regularly exercise but for less than ...
# 68   Maintenance - regularly exercising for 6 month...
# 69   Action - regularly exercise but for less than ...
# 74   Maintenance - regularly exercising for 6 month...
# 77   Contemplation - currently not doing exercise, ...
# 78   Contemplation - currently not doing exercise, ...
# 81   Action - regularly exercise but for less than ...
# 82   Priority - intensive exercise multiple times a...
# 87   Precontemplation - currently not doing exercis...
# 88   Priority - intensive exercise multiple times a...
# 89   Maintenance - regularly exercising for 6 month...
# 96      Preparation - doing exercise but not regularly
# 100     Preparation - doing exercise but not regularly
# 102  Priority - intensive exercise multiple times a...
# 105  Contemplation - currently not doing exercise, ...
# 106  Priority - intensive exercise multiple times a...
# 109     Preparation - doing exercise but not regularly
# 117  Maintenance - regularly exercising for 6 month...
#
#                                    past_activity_level  exercise_importance  \
# 3    Maintenance - regularly exercising for 6 month...                    8
# 5           Precontemplation - did not exercise at all                    8
# 6                 Preparation - exercised infrequently                    5
# 7    Maintenance - regularly exercising for 6 month...                    8
# 8                 Preparation - exercised infrequently                    7
# 9                 Preparation - exercised infrequently                    7
# 10   Maintenance - regularly exercising for 6 month...                    9
# 11   Contemplation - did not exercise but intended ...                    3
# 14   Maintenance - regularly exercising for 6 month...                    8
# 16   Maintenance - regularly exercising for 6 month...                   10
# 24   Maintenance - regularly exercising for 6 month...                    5
# 25   Maintenance - regularly exercising for 6 month...                    7
# 27   Maintenance - regularly exercising for 6 month...                    6
# 29          Precontemplation - did not exercise at all                    9
# 30   Priority - intensive exercise multiple times a...                    7
# 36                Preparation - exercised infrequently                    7
# 40   Maintenance - regularly exercising for 6 month...                    8
# 41   Maintenance - regularly exercising for 6 month...                   10
# 44                Preparation - exercised infrequently                    8
# 45          Precontemplation - did not exercise at all                    5
# 46   Maintenance - regularly exercising for 6 month...                    6
# 49   Priority - intensive exercise multiple times a...                    6
# 50                Preparation - exercised infrequently                    5
# 51   Maintenance - regularly exercising for 6 month...                    9
# 56   Priority - intensive exercise multiple times a...                    8
# 65   Maintenance - regularly exercising for 6 month...                    7
# 68   Contemplation - did not exercise but intended ...                    7
# 69   Maintenance - regularly exercising for 6 month...                    7
# 74   Maintenance - regularly exercising for 6 month...                    9
# 77                Preparation - exercised infrequently                    8
# 78   Maintenance - regularly exercising for 6 month...                    6
# 81   Maintenance - regularly exercising for 6 month...                    8
# 82          Precontemplation - did not exercise at all                    8
# 87          Precontemplation - did not exercise at all                    2
# 88                Preparation - exercised infrequently                    9
# 89                Preparation - exercised infrequently                    8
# 96   Maintenance - regularly exercising for 6 month...                    4
# 100  Maintenance - regularly exercising for 6 month...                    4
# 102  Priority - intensive exercise multiple times a...                    8
# 105         Precontemplation - did not exercise at all                    4
# 106  Action - regularly exercised but for less than...                    9
# 109  Contemplation - did not exercise but intended ...                    6
# 117  Maintenance - regularly exercising for 6 month...                   10
#
#                             prior_athlete  \
# 3                     Yes, in high school
# 5    Yes, in high school, Yes, in college
# 6                                      No
# 7                                      No
# 8                     Yes, in high school
# 9    Yes, in high school, Yes, in college
# 10   Yes, in high school, Yes, in college
# 11                                     No
# 14                        Yes, in college
# 16   Yes, in high school, Yes, in college
# 24   Yes, in high school, Yes, in college
# 25                    Yes, in high school
# 27   Yes, in high school, Yes, in college
# 29                                     No
# 30                    Yes, in high school
# 36                    Yes, in high school
# 40   Yes, in high school, Yes, in college
# 41                                     No
# 44                    Yes, in high school
# 45                    Yes, in high school
# 46                    Yes, in high school
# 49                    Yes, in high school
# 50                                     No
# 51   Yes, in high school, Yes, in college
# 56                    Yes, in high school
# 65                                     No
# 68                                     No
# 69   Yes, in high school, Yes, in college
# 74                    Yes, in high school
# 77                    Yes, in high school
# 78                                     No
# 81                    Yes, in high school
# 82                    Yes, in high school
# 87                                     No
# 88                    Yes, in high school
# 89                                     No
# 96                    Yes, in high school
# 100                   Yes, in high school
# 102                   Yes, in high school
# 105                                    No
# 106                   Yes, in high school
# 109                                    No
# 117  Yes, in high school, Yes, in college
#
#                                          sport_history  \
# 3                                        Vball, soccer
# 5    Water Polo/Swim in High School, Dragon Boat in...
# 6                                                  NaN
# 7                                                  NaN
# 8                                               tennis
# 9                                 Wrestling, Jiu Jitsu
# 10                                       Rowing, Rugby
# 11                                                 NaN
# 14                                      Snowboard Team
# 16                                              Soccer
# 24                                               Rugby
# 25                                                Swim
# 27                                              Soccer
# 29                                                 NaN
# 30                                            swimming
# 36                                               track
# 40   Swimming in high school and dragon boat in col...
# 41                                                 NaN
# 44                                              Tennis
# 45                                   wrestling, tennis
# 46                                            Swimming
# 49                                        Cheerleading
# 50                                                 NaN
# 51   Swimming (high school) and dance (high school ...
# 56                                      Cross country
# 65                                                 NaN
# 68                                                 NaN
# 69   Martial Arts, cross country, wrestling, latin ...
# 74                                                swim
# 77                                              Soccer
# 78                                                 NaN
# 81                                              tennis
# 82                                                golf
# 87                                                 NaN
# 88                                           Badminton
# 89                                                 NaN
# 96                                Competitive dancing
# 100                                               Swim
# 102                        Basketball, Track and Field
# 105                                                NaN
# 106                                             Tennis
# 109                                                NaN
# 117                            Water Polo and Swimming
#
#                                     exercise_locations  \
# 3                                           Off Campus
# 5    At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 6                                           Off Campus
# 7              Off Campus, Sports (IM, Club, Division)
# 8    At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 9    At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 10   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 11   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 14   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 16   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 24   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 25   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 27             Off Campus, Sports (IM, Club, Division)
# 29   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 30   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 36   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 40   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 41   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 44   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 45                                                 NaN
# 46                                          Off Campus
# 49                                          Off Campus
# 50   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 51   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 56   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 65   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 68   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 69   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 74                                          Off Campus
# 77             Off Campus, Sports (IM, Club, Division)
# 78                                          Off Campus
# 81   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 82                                          Off Campus
# 87                                                 NaN
# 88   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 89   At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 96                                          Off Campus
# 100  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 102  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 105  Inside the Residential Halls/Apartments, Off C...
# 106  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 109  At an on campus gym (Main Gym, RIMAC, Spanos, ...
# 117  At an on campus gym (Main Gym, RIMAC, Spanos, ...
#
#           off_campus_gym_freq         ...         proximity_importance  \
# 3         1 or 2 times a week         ...                          7.0
# 5                       Never         ...                          5.0
# 6                       Never         ...                          7.0
# 7         3 or 4 times a week         ...                          5.0
# 8                       Never         ...                          5.0
# 9         1 or 2 times a week         ...                          3.0
# 10        1 or 2 times a week         ...                          5.0
# 11                      Never         ...                          4.0
# 14      Less than once a week         ...                          7.0
# 16     Less than once a month         ...                          NaN
# 24                      Never         ...                          2.0
# 25      Less than once a week         ...                          3.0
# 27     Less than once a month         ...                          7.0
# 29   More than 5 times a week         ...                          7.0
# 30     Less than once a month         ...                          NaN
# 36                      Never         ...                          1.0
# 40                      Never         ...                          5.0
# 41   More than 5 times a week         ...                          5.0
# 44                      Never         ...                          7.0
# 45                      Never         ...                          3.0
# 46        3 or 4 times a week         ...                          6.0
# 49        1 or 2 times a week         ...                          7.0
# 50     Less than once a month         ...                          5.0
# 51        3 or 4 times a week         ...                          4.0
# 56                      Never         ...                          2.0
# 65                      Never         ...                          7.0
# 68        1 or 2 times a week         ...                          7.0
# 69                      Never         ...                          5.0
# 74                      Never         ...                          7.0
# 77     Less than once a month         ...                          6.0
# 78      Less than once a week         ...                          7.0
# 81                      Never         ...                          7.0
# 82   More than 5 times a week         ...                          6.0
# 87                      Never         ...                          6.0
# 88                      Never         ...                          4.0
# 89                      Never         ...                          3.0
# 96        1 or 2 times a week         ...                          7.0
# 100                     Never         ...                          4.0
# 102  More than 5 times a week         ...                          5.0
# 105                     Never         ...                          7.0
# 106       3 or 4 times a week         ...                          4.0
# 109    Less than once a month         ...                          4.0
# 117                     Never         ...                          1.0
#
#     equipment_importance time_importance class_importance friends_importance  \
# 3                    6.0             4.0              5.0                3.0
# 5                    7.0             6.0              4.0                2.0
# 6                    3.0             5.0              4.0                2.0
# 7                    3.0             4.0              7.0                2.0
# 8                    7.0             6.0              1.0                4.0
# 9                    5.0             4.0              1.0                7.0
# 10                   7.0             6.0              2.0                3.0
# 11                   5.0             3.0              7.0                6.0
# 14                   6.0             5.0              1.0                4.0
# 16                   NaN             NaN              NaN                NaN
# 24                   6.0             4.0              1.0                7.0
# 25                   6.0             2.0              1.0                NaN
# 27                   3.0             6.0              1.0                2.0
# 29                   5.0             6.0              1.0                4.0
# 30                   7.0             NaN              NaN                NaN
# 36                   2.0             3.0              4.0                5.0
# 40                   2.0             4.0              3.0                1.0
# 41                   7.0             6.0              1.0                3.0
# 44                   6.0             5.0              3.0                2.0
# 45                   7.0             5.0              4.0                6.0
# 46                   4.0             5.0              2.0                7.0
# 49                   5.0             6.0              1.0                4.0
# 50                   6.0             4.0              7.0                NaN
# 51                   3.0             7.0              NaN                2.0
# 56                   3.0             5.0              4.0                6.0
# 65                   6.0             5.0              4.0                3.0
# 68                   6.0             4.0              3.0                5.0
# 69                   6.0             4.0              7.0                3.0
# 74                   6.0             5.0              4.0                3.0
# 77                   5.0             4.0              1.0                3.0
# 78                   4.0             5.0              3.0                2.0
# 81                   5.0             2.0              1.0                4.0
# 82                   7.0             5.0              3.0                4.0
# 87                   5.0             3.0              2.0                7.0
# 88                   7.0             5.0              1.0                3.0
# 89                   7.0             4.0              6.0                2.0
# 96                   3.0             6.0              1.0                5.0
# 100                  7.0             6.0              5.0                3.0
# 102                  7.0             6.0              1.0                3.0
# 105                  6.0             4.0              3.0                5.0
# 106                  7.0             6.0              5.0                3.0
# 109                  5.0             3.0              2.0                6.0
# 117                  3.0             2.0              4.0                6.0
#
#     student_athlete_importance other_importance  \
# 3                          1.0              2.0
# 5                          3.0              1.0
# 6                          1.0              6.0
# 7                          1.0              6.0
# 8                          3.0              2.0
# 9                          6.0              2.0
# 10                         4.0              1.0
# 11                         1.0              2.0
# 14                         3.0              2.0
# 16                         7.0              NaN
# 24                         5.0              3.0
# 25                         7.0              5.0
# 27                         5.0              4.0
# 29                         2.0              3.0
# 30                         NaN              NaN
# 36                         6.0              7.0
# 40                         6.0              7.0
# 41                         2.0              4.0
# 44                         1.0              4.0
# 45                         1.0              2.0
# 46                         1.0              3.0
# 49                         3.0              2.0
# 50                         1.0              NaN
# 51                         5.0              1.0
# 56                         1.0              7.0
# 65                         1.0              2.0
# 68                         1.0              NaN
# 69                         2.0              1.0
# 74                         2.0              1.0
# 77                         2.0              NaN
# 78                         1.0              6.0
# 81                         3.0              6.0
# 82                         2.0              1.0
# 87                         1.0              4.0
# 88                         2.0              6.0
# 89                         1.0              5.0
# 96                         4.0              2.0
# 100                        1.0              2.0
# 102                        2.0              4.0
# 105                        1.0              2.0
# 106                        2.0              1.0
# 109                        1.0              7.0
# 117                        7.0              5.0
#
#                                         main_motivator  \
# 3                                                  NaN
# 5                        Get Stronger/better physique
# 6                               I don't go to the gym.
# 7                                                  NaN
# 8                                   health, body image
# 9                                  Fitness/Competition
# 10                                       It's my hobby
# 11                                                 NaN
# 14                        Feeling healthy and in shape
# 16                                                 NaN
# 24                          Bitches, money, icy gainz
# 25                   To clear my mind and stay healthy
# 27                                                 NaN
# 29                   Building muscle, powerlifting PRs
# 30                                                 NaN
# 36                                                 NaN
# 40                    It’s mandatory for my club sport
# 41                                                Zyzz
# 44                                          Extra time
# 45                                     Look good naked
# 46                                              Health
# 49                              Health, physical looks
# 50                                           Rec class
# 51   To practice dance with my partner and to get r...
# 56                                        Get in shape
# 65                                               Gains
# 68               Staying active / engaging in a hobby
# 69                                           rec class
# 74                                                 NaN
# 77   I feel gross if I don't go. It makes my mood b...
# 78                                              health
# 81                                                 NaN
# 82                                               booty
# 87                                                 NaN
# 88                                               Gains
# 89                 Staying healthy + getting stronger
# 96                             not sit around all day
# 100                                                NaN
# 102                                      Bodybuilding
# 105  To take care of my body as the temple of the H...
# 106                  I'm trying to improve my physique
# 109  To get stronger/going with my friend to keep m...
# 117                                           Fit Body
#
#                                       attend_gym_times               email
# 3    Late Morning (9AM - 11AM), Afternoon (12PM - 3...      morel@ucsd.edu
# 5    Late Morning (9AM - 11AM), Afternoon (12PM - 3...     ringle@ucsd.edu
# 6                               I don't go to the gym.     jas139@ucsd.edu
# 7                                  Evening (4PM - 7PM)                 NaN
# 8           Night (8PM - 12AM), I don't go to the gym.     p9phan@ucsd.edu
# 9       Early Morning (4AM - 8AM), Evening (4PM - 7PM)     ajr062@ucsd.edu
# 10         Afternoon (12PM - 3PM), Evening (4PM - 7PM)     ajs021@ucsd.edu
# 11             Evening (4PM - 7PM), Night (8PM - 12AM)     naskar@ucsd.edu
# 14                           Late Morning (9AM - 11AM)   hrhoffma@ucsd.edu
# 16   Early Morning (4AM - 8AM), Late Morning (9AM -...     amr052@ucsd.edu
# 24   Late Morning (9AM - 11AM), Afternoon (12PM - 3PM)                 NaN
# 25             Evening (4PM - 7PM), Night (8PM - 12AM)       Ddun@ucsd.edu
# 27                                 Evening (4PM - 7PM)   Mdaruval@ucsd.edu
# 29       Early Morning (4AM - 8AM), Night (8PM - 12AM)     tcn001@ucsd.edu
# 30                                 Evening (4PM - 7PM)     ksliou@ucsd.edu
# 36      Late Morning (9AM - 11AM), Evening (4PM - 7PM)     jkc026@ucsd.edu
# 40       Early Morning (4AM - 8AM), Night (8PM - 12AM)      ofong@ucsd.edu
# 41   Afternoon (12PM - 3PM), Evening (4PM - 7PM), N...   nvaghasi@ucsd.edu
# 44         Afternoon (12PM - 3PM), Evening (4PM - 7PM)    k8zheng@ucsd.edu
# 45                              Afternoon (12PM - 3PM)     ash055@ucsd.edu
# 46             Evening (4PM - 7PM), Night (8PM - 12AM)    apervan@ucsd.edu
# 49   Late Morning (9AM - 11AM), Afternoon (12PM - 3PM)     jms049@ucsd.edu
# 50      Late Morning (9AM - 11AM), Evening (4PM - 7PM)     xig086@ucsd.edu
# 51             Evening (4PM - 7PM), Night (8PM - 12AM)    nbwells@ucsd.edu
# 56                                  Night (8PM - 12AM)    svillar@ucsd.edu
# 65       Late Morning (9AM - 11AM), Night (8PM - 12AM)     ejc042@ucsd.edu
# 68             Evening (4PM - 7PM), Night (8PM - 12AM)    s1panda@ucsd.edu
# 69         Afternoon (12PM - 3PM), Evening (4PM - 7PM)     syl127@ucsd.edu
# 74         Afternoon (12PM - 3PM), Evening (4PM - 7PM)     soy030@ucsd.edu
# 77                                  Night (8PM - 12AM)     kmw031@ucsd.edu
# 78   Early Morning (4AM - 8AM), Afternoon (12PM - 3...                 NaN
# 81                              Afternoon (12PM - 3PM)   amdhingr@ucsd.edu
# 82                                  Night (8PM - 12AM)   jmhowell@ucsd.edu
# 87                              I don't go to the gym.                 NaN
# 88                              Afternoon (12PM - 3PM)      jdyee@ucsd.edu
# 89         Afternoon (12PM - 3PM), Evening (4PM - 7PM)                 NaN
# 96   Late Morning (9AM - 11AM), Afternoon (12PM - 3PM)  Bcvargas@ucsd.edu
# 100                          Late Morning (9AM - 11AM)     aljiao@ucsd.edu
# 102        Afternoon (12PM - 3PM), Evening (4PM - 7PM)   Bmiramon@ucsd.edu
# 105                                Evening (4PM - 7PM)     vac008@ucsd.edu
# 106     Late Morning (9AM - 11AM), Evening (4PM - 7PM)    lnathan@ucsd.edu
# 109                          Late Morning (9AM - 11AM)   dhowanec@ucsd.edu
# 117            Evening (4PM - 7PM), Night (8PM - 12AM)    mrafter@ucsd.edu
#
# [43 rows x 44 columns]

# %% [markdown]
# Key:
# Never = 0
# Once a month = 1
# Less than Once a week = 2
# 1 or 2 times a week = 3
# 3 ot 4 times a week = 4
# more than 5 times a week 5

# %%
df = df.replace(["Never", "Less than once a month", "Less than once a week", "1 or 2 times a week", "3 or 4 times a week", "More than 5 times a week"], [0, 1, 2, 3, 4, 5])

challenge = df
transport = df

# %% [markdown]
# On Campus Gym Frequency vs Off Campus Gym Frequency

# %%
plt.scatter(list(df['off_campus_gym_freq']), list(df['on_campus_gym_freq']))
plt.xlabel("Off Campus Gym Frequency")
plt.ylabel("On Campus Gym Frequency")
plt.show()

# %% [markdown]
# Avg Commute time and Off Campus Gym Freq

# %%
df = df.replace([None, "< 5 minutes", "6 - 10 minutes", "11 - 15 minutes", "16 - 20 minutes", "21 - 25 minutes"],[0, 5, 10, 15, 20, 25])

# %%
df["avg_commute_off_campus"] = df[['avg_commute_ss_off_campus','avg_commute_mwf_off_campus', 'avg_commute_tth_off_campus']].mean(axis=1)

# %%
plt.scatter(list(df['avg_commute_off_campus']), list(df['off_campus_gym_freq']))
plt.xlabel("Average Commute Off Campus")
plt.ylabel("Off Campus Gym Frequency")
plt.show()

# %% [markdown]
# Commute Challenges

# %%
#"commute_challenges_mwf_on_campus", "commute_challenges_tth_on_campus", "commute_challenges_ss_on_campus"
def clean_challenges (row):
    cleaned = ''
    for entry in [row["commute_challenges_mwf_off_campus"], row["commute_challenges_tth_off_campus"],
                  row["commute_challenges_ss_off_campus"]]:
        print(entry)
        if entry is np.nan:
            cleaned += 'X'
            continue
        if 'uphill' in entry:
            cleaned += 'U'
        if 'stair' in entry:
            cleaned += 'S'
    return cleaned

# %%
challenge['week_challenge'] = challenge.apply(lambda row: clean_challenges(row), axis=1)
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Going uphill for longer than 3 minutes, Going up a staircase with 5 or more stairs
# Going uphill for longer than 3 minutes, Going up a staircase with 5 or more stairs
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Going uphill for longer than 3 minutes
# Going uphill for longer than 3 minutes
# Going uphill for longer than 3 minutes
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Going up a staircase with 5 or more stairs
# Going up a staircase with 5 or more stairs
# Going up a staircase with 5 or more stairs
# nan
# nan
# nan
# nan
# nan
# nan
# Going up a staircase with 5 or more stairs
# Going up a staircase with 5 or more stairs
# Going up a staircase with 5 or more stairs
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Going up a staircase with 5 or more stairs
# Going up a staircase with 5 or more stairs
# Going up a staircase with 5 or more stairs
# nan
# nan
# nan
# Going uphill for longer than 3 minutes
# Going uphill for longer than 3 minutes
# Going uphill for longer than 3 minutes, Going up a staircase with 5 or more stairs
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
none = challenge[challenge['week_challenge'].str.contains("XXX")]
uphill = challenge[challenge['week_challenge'].str.contains("U")]
stairs = challenge[challenge['week_challenge'].str.contains("S")]
stairs['off_campus_gym_freq']
# Out:
# 8      0
# 46     4
# 51     4
# 96     3
# 102    5
# Name: off_campus_gym_freq, dtype: int64

# %%
none_freq = none['off_campus_gym_freq'].mean()
uphill_freq = uphill['off_campus_gym_freq'].mean()
stairs_freq = stairs['off_campus_gym_freq'].mean()

# %%
challenge_off_freq = pd.DataFrame({'none': none_freq, 'uphill': uphill_freq, 'stairs': stairs_freq})
labels = ('none', 'uphill', 'stairs')
ax = challenge_off_freq.plot.bar(rot=0,figsize=(20,10))
y_pos = np.arange(len(labels))
plt.xticks(y_pos, labels)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-40cf6350c0f5> in <module>()
#       1 d = {none_freq, uphill_freq, stairs_freq}
# ----> 2 challenge_off_freq = pd.DataFrame(data=d)
#       3 labels = ('none', 'uphill', 'stairs')
#       4 ax = challenge_off_freq.plot.bar(rot=0,figsize=(20,10))
#       5 y_pos = np.arange(len(labels))
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     352                                          copy=False)
#     353             else:
# --> 354                 raise ValueError('DataFrame constructor not properly called!')
#     355
#     356         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %% [markdown]
# Transportation

# %%
def clean_transport (row):
    cleaned = ''
    for entry in [row["transportation_mwf_on_campus"], row["transportation_tth_on_campus"],
                  row["transportation_ss_on_campus"]]:
        if entry is np.nan:
            cleaned += 'X'
            continue
        if 'Walk' in entry:
            cleaned += 'W'
        if 'Bike' in entry:
            cleaned += 'B'
        if 'Car' in entry:
            cleaned += 'C'
        if 'Skateboard' in entry:
            cleaned += 'K'
        if 'Bus' in entry:
            cleaned += 'S'
    return cleaned

# %%
transport = df
transport['week_transport'] = transport.apply(lambda row: clean_transport(row), axis=1)

# %%
none = transport[transport['week_transport'].str.contains('XXX')]
walk = transport[transport['week_transport'].str.contains("W")]
bike = transport[transport['week_transport'].str.contains("B")]
car = transport[transport['week_transport'].str.contains("C")]
skateboard = transport[transport['week_transport'].str.contains("K")]
shuttle = transport[transport['week_transport'].str.contains("S")]

# %%
none_freq = none['off_campus_gym_freq'].mean()
walk_freq = walk['off_campus_gym_freq'].mean()
bike_freq = bike['off_campus_gym_freq'].mean()
car_freq = car['off_campus_gym_freq'].mean()
skateboard_freq = skateboard['off_campus_gym_freq'].mean()
shuttle_freq = shuttle['off_campus_gym_freq'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     118                 else:
# --> 119                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     120             except Exception:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna)
#     311     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 312     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     313
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims)
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#
# TypeError: must be str, not int
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-aabf942949ad> in <module>()
# ----> 1 none_freq = none['off_campus_gym_freq'].mean()
#       2 walk_freq = walk['off_campus_gym_freq'].mean()
#       3 bike_freq = bike['off_campus_gym_freq'].mean()
#       4 car_freq = car['off_campus_gym_freq'].mean()
#       5 skateboard_freq = skateboard['off_campus_gym_freq'].mean()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#    6340                                       skipna=skipna)
#    6341         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 6342                             numeric_only=numeric_only)
#    6343
#    6344     return set_function_name(stat_func, name, cls)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    2379                                           'numeric_only.'.format(name))
#    2380             with np.errstate(all='ignore'):
# -> 2381                 return op(delegate, skipna=skipna, **kwds)
#    2382
#    2383         return delegate._reduce(op=op, name=name, axis=axis, skipna=skipna,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      60             try:
#      61                 with np.errstate(invalid='ignore'):
# ---> 62                     return f(*args, **kwargs)
#      63             except ValueError as e:
#      64                 # we want to transform an object array
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     120             except Exception:
#     121                 try:
# --> 122                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     123                 except ValueError as e:
#     124                     # we want to transform an object array
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna)
#     310         dtype_count = dtype
#     311     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 312     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     313
#     314     if axis is not None and getattr(the_sum, 'ndim', False):
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#      34 def _prod(a, axis=None, dtype=None, out=None, keepdims=False):
#
# TypeError: must be str, not int

# %%
transport_on_freq = pd.DataFrame({none_freq, walk_freq, bike_freq, car_freq, skateboard_freq, shuttle_freq})
labels = ('none','walk/jog', 'bike', 'car', 'skateboard', 'shuttle')
ax = transport_on_freq.plot.bar(rot=0,figsize=(20,10))
y_pos = np.arange(len(labels))
plt.xticks(y_pos, labels)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-b5af67d345e8> in <module>()
# ----> 1 transport_on_freq = pd.DataFrame({none_freq, walk_freq, bike_freq, car_freq, skateboard_freq, shuttle_freq})
#       2 labels = ('none','walk/jog', 'bike', 'car', 'skateboard', 'shuttle')
#       3 ax = transport_on_freq.plot.bar(rot=0,figsize=(20,10))
#       4 y_pos = np.arange(len(labels))
#       5 plt.xticks(y_pos, labels)
#
# NameError: name 'walk_freq' is not defined
